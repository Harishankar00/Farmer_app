# %%
import pandas as pd

# %%
df = pd.read_csv('plant_data.csv')
df
# Out:
#                                            class_name  plant_name  \
# 0                                  Apple___Apple_scab       Apple
# 1                                   Apple___Black_rot       Apple
# 2                            Apple___Cedar_apple_rust       Apple
# 3                                     Apple___healthy       Apple
# 4                                 Blueberry___healthy   Blueberry
# 5                   Cherry_(including_sour)___healthy      Cherry
# 6            Cherry_(including_sour)___Powdery_mildew      Cherry
# 7   Corn_(maize)___Cercospora_leaf_spot_Gray_leaf_...        Corn
# 8                         Corn_(maize)___Common_rust_        Corn
# 9                              Corn_(maize)___healthy        Corn
# 10                Corn_(maize)___Northern_Leaf_Blight        Corn
# 11                                  Grape___Black_rot       Grape
# 12                       Grape___Esca_(Black_Measles)       Grape
# ...

# %%
df.isnull().sum()
# Out:
# class_name                0
# plant_name                0
# disease_name              0
# impact                    0
# base_yield_kg_per_acre    0
# yield_reduction_factor    0
# recommendations           0
# dtype: int64
